# %%
# %matplotlib inline
import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None,real_dim), name = 'inputs_real')
    inputs_z = tf.placeholder(tf.float32, (None,z_dim), name = 'inputs_z')
    return inputs_real, inputs_z

# %%
def generator(z, out_dim, n_units=128, reuse=False,  alpha=0.01):
    ''' build generator network.
    '''
    with tf.variable_scope('generator',reuse=reuse):
        h1 = tf.layers.dense(z,n_units,activation=None) 
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1,h1)
        
        logits = tf.layers.dense(h1,out_dim, activation=None)
        out = tf.tanh(logits)
        
        return out

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    ''' build discriminator network.
    '''
    with tf.variable_scope('discriminator',reuse=reuse):
        h1 = tf.layers.dense(x,n_units, activation=None)   #tf.add(tf.matmul(w1,x),b1)
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1,h1)
        
        logits = tf.layers.dense(h1, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %%
input_size = 784    # discriminator的输入大小（28x28） 
z_size = 100        # generator 的输入特征向量的大小
g_hidden_size = 128 # generator的隐藏层的大小
d_hidden_size = 128 # discriminator的隐藏层的大小
alpha = 0.01        # leaky factor
smooth = 0.1        # Label smoothing

# %%
tf.reset_default_graph()

input_real, input_z = model_inputs(input_size,z_size)

# genertor network
g_model = generator(input_z, input_size, g_hidden_size)

# disriminator network
d_model_real, d_logits_real = discriminator(input_real)
d_model_fake, d_logits_fake = discriminator(g_model,reuse=True)

# %%
# 计算losses
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_logits_real) * (1 - smooth)))

d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_logits_fake)))

d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_logits_fake)))

# %%
# optimizers
learning_rate = 0.002

t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(d_loss,var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(g_loss,var_list=g_vars)

# %%
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory `checkpoints': File exists

# %%
batch_size = 100
epochs = 100
samples = []
losses = []
# 只保存generator的变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            # 处理images
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            # 传入Generator的随机噪声
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            
            # 运行optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # 获取loss，并print
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # save losses
        losses.append((train_loss_d, train_loss_g))
        
        # generator生成数据采样
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, reuse=True),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# 保存generator的采样
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/100... Discriminator Loss: 0.3515... Generator Loss: 4.4938
# Epoch 2/100... Discriminator Loss: 0.4104... Generator Loss: 2.8020
# Epoch 3/100... Discriminator Loss: 0.4756... Generator Loss: 3.6984
# Epoch 4/100... Discriminator Loss: 0.5212... Generator Loss: 2.6241
# Epoch 5/100... Discriminator Loss: 2.3772... Generator Loss: 1.3672
# Epoch 6/100... Discriminator Loss: 4.3140... Generator Loss: 1.9360
# Epoch 7/100... Discriminator Loss: 1.4698... Generator Loss: 0.8264
# Epoch 8/100... Discriminator Loss: 1.5321... Generator Loss: 1.2242
# Epoch 9/100... Discriminator Loss: 2.6812... Generator Loss: 1.2782
# Epoch 10/100... Discriminator Loss: 5.1883... Generator Loss: 0.8874
# Epoch 11/100... Discriminator Loss: 1.3076... Generator Loss: 2.1427
# Epoch 12/100... Discriminator Loss: 0.9071... Generator Loss: 2.9136
# Epoch 13/100... Discriminator Loss: 0.9750... Generator Loss: 2.0451
# Epoch 14/100... Discriminator Loss: 2.8613... Generator Loss: 0.8099
# Epoch 15/100... Discriminator Loss: 1.5792... Generator Loss: 0.8568
# Epoch 16/100... Discriminator Loss: 2.1522... Generator Loss: 1.2152
# Epoch 17/100... Discriminator Loss: 2.9067... Generator Loss: 0.5972
# Epoch 18/100... Discriminator Loss: 1.2932... Generator Loss: 2.1740
# Epoch 19/100... Discriminator Loss: 1.4326... Generator Loss: 0.6662
# Epoch 20/100... Discriminator Loss: 0.9878... Generator Loss: 1.1961
# Epoch 62/100... Discriminator Loss: 0.9900... Generator Loss: 2.3484
# Epoch 63/100... Discriminator Loss: 0.8766... Generator Loss: 2.2948
# Epoch 64/100... Discriminator Loss: 1.0456... Generator Loss: 1.6479
# Epoch 65/100... Discriminator Loss: 0.9642... Generator Loss: 1.6539
# Epoch 66/100... Discriminator Loss: 1.0691... Generator Loss: 1.6585
# Epoch 67/100... Discriminator Loss: 1.0619... Generator Loss: 2.0080
# Epoch 68/100... Discriminator Loss: 0.9024... Generator Loss: 1.7794
# Epoch 69/100... Discriminator Loss: 0.9454... Generator Loss: 1.8627
# Epoch 70/100... Discriminator Loss: 0.8472... Generator Loss: 2.2536
# Epoch 71/100... Discriminator Loss: 0.8779... Generator Loss: 2.3255
# Epoch 72/100... Discriminator Loss: 0.9073... Generator Loss: 1.9266
# Epoch 73/100... Discriminator Loss: 0.9044... Generator Loss: 2.1413
# Epoch 74/100... Discriminator Loss: 0.9466... Generator Loss: 1.6304
# Epoch 75/100... Discriminator Loss: 0.8915... Generator Loss: 1.6868
# Epoch 76/100... Discriminator Loss: 0.8050... Generator Loss: 2.5068
# Epoch 77/100... Discriminator Loss: 0.9799... Generator Loss: 1.6786
# Epoch 78/100... Discriminator Loss: 0.9529... Generator Loss: 1.8657
# Epoch 79/100... Discriminator Loss: 1.0931... Generator Loss: 1.9963
# Epoch 80/100... Discriminator Loss: 0.9452... Generator Loss: 1.6893
# Epoch 81/100... Discriminator Loss: 0.9433... Generator Loss: 1.8467
# Epoch 82/100... Discriminator Loss: 0.9648... Generator Loss: 1.8850
# Epoch 83/100... Discriminator Loss: 0.9305... Generator Loss: 2.3043
# Epoch 84/100... Discriminator Loss: 0.8332... Generator Loss: 2.3031
# Epoch 85/100... Discriminator Loss: 1.1164... Generator Loss: 1.4761
# Epoch 86/100... Discriminator Loss: 0.9812... Generator Loss: 1.7644
# Epoch 87/100... Discriminator Loss: 0.8922... Generator Loss: 1.9961
# Epoch 88/100... Discriminator Loss: 1.0330... Generator Loss: 1.4934
# Epoch 89/100... Discriminator Loss: 0.8789... Generator Loss: 2.4492
# Epoch 90/100... Discriminator Loss: 1.0107... Generator Loss: 1.6074
# Epoch 91/100... Discriminator Loss: 1.0773... Generator Loss: 1.5579
# Epoch 92/100... Discriminator Loss: 1.2699... Generator Loss: 2.2861
# Epoch 93/100... Discriminator Loss: 1.0386... Generator Loss: 1.3934
# Epoch 94/100... Discriminator Loss: 0.9206... Generator Loss: 1.7818
# Epoch 95/100... Discriminator Loss: 1.1045... Generator Loss: 1.7869
# Epoch 96/100... Discriminator Loss: 1.4483... Generator Loss: 1.1864
# Epoch 97/100... Discriminator Loss: 1.0667... Generator Loss: 1.5620
# Epoch 98/100... Discriminator Loss: 1.0338... Generator Loss: 1.7522
# Epoch 99/100... Discriminator Loss: 1.0175... Generator Loss: 1.6992
# Epoch 100/100... Discriminator Loss: 0.9692... Generator Loss: 2.0976

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# 加载训练时generator的采样
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, reuse=True),
                   feed_dict={input_z: sample_z})
_ = view_samples(0, [gen_samples])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/generator.ckpt
